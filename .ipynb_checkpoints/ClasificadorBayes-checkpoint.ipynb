# %%
#Importamos librerias utiles
import pandas as pd
import numpy as np
import math
import sklearn
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

#leemos nuestros datos
pico = pd.read_csv('DatosZonaPico.csv',sep=',')
Pico = pd.DataFrame(pico)
cachete = pd.read_csv('DatosZonaCachete.csv',sep=',')
Cachete = pd.DataFrame(cachete)
cuello = pd.read_csv('DatosZonaCuello.csv',sep=',')
Cuello = pd.DataFrame(cuello)

#dado que la columna Var1 no aporta datos utiles, la descartamos
Cachete = Cachete.drop(columns = ['Var1'])
Cuello = Cuello.drop(columns = ['Var1'])
Pico = Pico.drop(columns = ['Var1'])

#mostramos las primeras 10 filas de un dataframe
Cachete.head(10)
# Out:
#         media      varianza  asimetria   curtosis  entropia  contraste  \
# 0   83.890625   9466.631127   1.698557   7.044050  0.851806   0.013920
# 1   83.867188  59045.166605   4.191150  23.352161  0.967662   0.007542
# 2   69.968750  10482.210784   1.211034   3.279414  0.999956   0.003339
# 3   33.515625   2414.705637   2.491578  13.102371  0.935456   0.007190
# 4   31.531250   2021.606863   1.489232   4.374694  0.972305   0.006786
# 5  100.101562  16955.244547   1.141830   3.560725  0.984047   0.008298
# 6  129.976562  27044.407292   1.089453   2.849137  0.851806   0.018132
# 7   88.371094  14708.289200   1.655309   5.201897  0.908910   0.015441
# 8   93.660156   9485.087975   1.071074   3.527071  0.805028   0.011511
# 9  108.781250  17184.665686   1.345566   4.095803  0.846354   0.017259
#
#    correlacion   energia  homogeneidad
# 0     0.994203  0.901224      0.997731
# 1     0.994359  0.902242      0.998310
# 2     0.993949  0.917516      0.998834
# 3     0.992016  0.959531      0.998659
# 4     0.989733  0.961862      0.998876
# 5     0.995753  0.883347      0.998041
# 6     0.995152  0.850431      0.997510
# 7     0.993368  0.896396      0.998130
# 8     0.994621  0.890437      0.998041
# 9     0.994185  0.873381      0.997877

# %%
#Mostramos la informacion de cada dataframe
Cachete.info()
Pico.info()
Cuello.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   media         50 non-null     float64
#  1   varianza      50 non-null     float64
#  2   asimetria     50 non-null     float64
#  3   curtosis      50 non-null     float64
#  4   entropia      50 non-null     float64
#  5   contraste     50 non-null     float64
#  6   correlacion   50 non-null     float64
#  7   energia       50 non-null     float64
#  8   homogeneidad  50 non-null     float64
# dtypes: float64(9)
# memory usage: 3.6 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   media         50 non-null     float64
#  1   varianza      50 non-null     float64
#  2   asimetria     50 non-null     float64
#  3   curtosis      50 non-null     float64
#  4   entropia      50 non-null     float64
#  5   contraste     50 non-null     float64
#  6   correlacion   50 non-null     float64
#  7   energia       50 non-null     float64
#  8   homogeneidad  50 non-null     float64
# dtypes: float64(9)
# memory usage: 3.6 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   media         50 non-null     float64
#  1   varianza      50 non-null     float64
#  2   asimetria     50 non-null     float64
#  3   curtosis      50 non-null     float64
#  4   entropia      50 non-null     float64
#  5   contraste     50 non-null     float64
#  6   correlacion   50 non-null     float64
#  7   energia       50 non-null     float64
#  8   homogeneidad  50 non-null     float64
# dtypes: float64(9)
# memory usage: 3.6 KB

# %%
#Definimos nuestros conjuntos de entrenamiento y validacion con el 70% entrenamiento y 30% evaluacion
#train se construye a partir de la funcion sample() donde frac es el porcentaje de los datos
#random_state es la semilla del numero aleatorio, esta funcion por default tiene desactivado
#el ingreso de datos por reemplazo, es decir no se pueden repetir filas
#el conjunto test se construye a partir del train quitando todos los indices que tiene train,
#es decir hace una operacion de conjuntos del conjunto universo Spam resta el conjunto train 
#y guarda lo que resta en test
trainPico = Pico.sample(frac=0.7,random_state=0)
testPico = Pico.drop(trainPico.index)
#añadimos una nueva columna con la clase perteneciente, solo en los datos test
testPico['Clase'] = 'Pico'

trainCachete = Cachete.sample(frac=0.7,random_state=0)
testCachete = Cachete.drop(trainCachete.index)
#añadimos una nueva columna con la clase perteneciente, solo en los datos test
testCachete['Clase'] = 'Cachete'

trainCuello = Cuello.sample(frac=0.7,random_state=0)
testCuello = Cuello.drop(trainCuello.index)
#añadimos una nueva columna con la clase perteneciente, solo en los datos test
testCuello['Clase'] = 'Cuello'

#reseteamos los indices con la funcion reset_index. drop=True lo usamos para evitar que se
#anada una columna del indice anterior
trainPico.reset_index(drop=True,inplace=True)
testPico.reset_index(drop=True,inplace=True)

trainCachete.reset_index(drop=True,inplace=True)
testCachete.reset_index(drop=True,inplace=True)

trainCuello.reset_index(drop=True,inplace=True)
testCuello.reset_index(drop=True,inplace=True)

#Nuestro conjunto de datos debe ser un conjunto de las particiones recien hechas. Para ello definimos
#un nuevo dataframe llamado Test
frames = [testCachete, testCuello, testPico]
Test = pd.concat(frames)
Test.reset_index(drop=True,inplace=True)
Test = Test.drop(columns = ['Clase'])

#se crea un nuevo array TestClases ya que olvide hacerlo desde un principio
#y eso me evita modificar bastante codigo (debuging chafa)
#TestClases es igual a Test pero con la columna clases.
#TestClases = pd.concat(frames)
frame = [testCachete['Clase'],testCuello['Clase'],testPico['Clase']]
ClasesReales = pd.concat(frame)
ClasesReales.reset_index(drop=True,inplace=True)

#Mostramos un dataframe recien creado
Test.head(45)
# Out:
#          media       varianza  asimetria   curtosis  entropia  contraste  \
# 0    83.890625    9466.631127   1.698557   7.044050  0.851806   0.013920
# 1    33.515625    2414.705637   2.491578  13.102371  0.935456   0.007190
# 2   129.976562   27044.407292   1.089453   2.849137  0.851806   0.018132
# 3   108.781250   17184.665686   1.345566   4.095803  0.846354   0.017259
# 4    41.867188    9897.197978   3.503589  15.631245  0.935456   0.013032
# 5    37.195312    1874.989154   1.209834   3.970218  0.912999   0.009031
# 6   125.851562   33358.456311   1.815782   5.696459  0.857148   0.013286
# 7    70.285156    8604.581112   1.517928   4.998017  0.912999   0.013647
# 8    96.023438   20198.117096   1.389435   3.795411  0.994666   0.012060
# 9    90.093750   21156.775490   1.918872   6.027364  0.945373   0.013150
# 10   26.988281    5290.450843   3.376944  14.199435  0.928362   0.003644
# 11   44.285156    3138.620328   1.218416   3.611419  0.942163   0.006504
# 12   29.046875    2873.809559   2.633306  11.233252  0.970029   0.011327
# 13   46.593750    4335.700980   1.615272   6.361075  0.994666   0.004283
# 22     0.965873  0.872245      0.997491
# 23     0.888671  0.986101      0.999219
# 24     0.964640  0.862428      0.997951
# 25     0.965889  0.960230      0.998691
# 26     0.793447  0.993123      0.999435
# 27     0.940869  0.950290      0.998728
# 28     0.877382  0.993793      0.999667
# 29     0.943157  0.954739      0.998173
# 30     0.987208  0.929674      0.998468
# 31     0.967444  0.973415      0.999062
# 32     0.988933  0.910094      0.998421
# 33     0.986655  0.902184      0.998372
# 34     0.971785  0.969027      0.999249
# 35     0.974489  0.953069      0.998329
# 36     0.985838  0.908778      0.998533
# 37     0.980998  0.914506      0.997595
# 38     0.975335  0.955158      0.999369
# 39     0.971111  0.946243      0.999245
# 40     0.963356  0.981705      0.999192
# 41     0.979904  0.970574      0.999360
# 42     0.971246  0.989412      0.999601
# 43     0.959050  0.986771      0.999648
# 44     0.971654  0.973574      0.999222

# %% [markdown]
# ### Un poco de teoría
#
# El clasificador naive Bayes es una forma de aprendizaje supervisado. El nombre de naive o ingenuo proviene de que este tipo de clasificadores se supone que cada par de caracteristicas es condicionalmente independiente entre sí.
#
# Usando el teorema de Bayes es posible deducir que para cada clase $y$ y un vector de características $\vec{x} = x_1 , x_2 ,..., x_n$ tenemos que:
#
# $$P(y| \vec{x}) \approx P(y)\prod_{i=1}^{n}P(x_i | y)$$
# <br>
# Donde asumimos que cada probabilidad $P(x_i | y)$ sigue una distribucion bien definida. $P(y)$ sera la probabilidad a priori.
# De esta manera para cada columna de cada dataframe asumiremos que siguen una distribucion de probabilidad Gausiana o normal dada por:
#
# $$P(x_i | y) = \frac{1}{\sqrt{2 \pi \sigma_{y}^{2}}} exp \left( - \frac{(x_y - \mu_y )^2}{2 \sigma_{y}^{2}}  \right)$$
# <br>
# El valor estimado $\hat{y}$ vendrá dado por:
# <br>
# $$\hat{y} = argmax_y P(y)\prod_{i=1}^{n}P(x_i | y)$$
# <br>
# Dado que asumimos que todas las clases (columnas de la tabla) siguen una distribución normal, debemos calcular $\sigma_{y}^{2}$ y $\mu_y$ para cada una de ellas, para posteriormente calcular $P(x_i | y)$ y finalmente obtener $P(y| \vec{x})$

# %% [markdown]
# ### Observación de las Imágenes
#
# Notemos que se dividió la imagen en tres regiones: Pico, Cachete y Cuello. Cada imagen contiene dichas regiones por lo que la probabilidad a priori de cada una de las tres clases de interés es $P(y)=\frac{1}{3}$

# %%
#calculamos la media de cada columna para cada dataframe
mediaPico = trainPico.mean(axis=0)
mediaCuello = trainCuello.mean(axis=0)
mediaCachete = trainCachete.mean(axis=0)

#calculamos la varianza de cada columna para cada dataframe
varianzaPico = trainPico.var(axis=0)
varianzaCuello = trainCuello.var(axis=0)
varianzaCachete = trainCachete.var(axis=0)

# %% [markdown]
# ### Clasificacion

# %%
#Convertimos el dataframe Test a un array numpy
arrayTest = Test.to_numpy()

#Imprimimos es array reciencreado
print(arrayTest)
# Out:
# [[8.38906250e+01 9.46663113e+03 1.69855712e+00 7.04404984e+00
#   8.51806189e-01 1.39198388e-02 9.94202731e-01 9.01224202e-01
#  [3.89804688e+01 2.87017609e+03 1.73470424e+00 5.02946626e+00
#   8.05027956e-01 7.84282417e-03 9.74488962e-01 9.53068556e-01
#   9.98328989e-01]
#  [8.02500000e+01 1.20069490e+04 1.07517981e+00 2.94837412e+00
#   9.97841573e-01 5.57920665e-03 9.85837695e-01 9.08778023e-01
#   9.98532954e-01]
#  [7.23515625e+01 9.44789161e+03 1.52570575e+00 5.35393027e+00
#   9.85687679e-01 8.72572892e-03 9.80997677e-01 9.14506272e-01
#   9.97595259e-01]
#  [5.65898438e+01 1.14140154e+04 1.94410222e+00 5.52828016e+00
#   9.88699408e-01 1.71884649e-03 9.75334777e-01 9.55158019e-01
#   9.99368934e-01]
#  [4.57148438e+01 9.94576543e+03 2.30440132e+00 6.91908792e+00
#   9.88699408e-01 2.60175125e-03 9.71111205e-01 9.46242945e-01
#   9.99244717e-01]
#  [2.38593750e+01 2.11748603e+03 5.42852224e+00 3.89091250e+01
#   5.65101332e-01 5.03443563e-03 9.63356175e-01 9.81705224e-01
#   9.99192029e-01]
#  [3.00351562e+01 1.42721052e+03 1.14385852e+00 3.80388016e+00
#   9.99955972e-01 2.69098099e-03 9.79904318e-01 9.70573507e-01
#   9.99360403e-01]
#  [8.99609375e+00 1.45313710e+02 1.39871853e+00 4.41954505e+00
#   9.99823883e-01 1.27739412e-03 9.71245980e-01 9.89412242e-01
#   9.99600814e-01]
#  [1.79570312e+01 1.20409619e+03 2.17532579e+00 7.42574609e+00
#   9.54434003e-01 7.98371323e-04 9.59050436e-01 9.86771162e-01
#   9.99647777e-01]
#  [2.70468750e+01 1.13770760e+03 1.42286205e+00 4.57653155e+00
#   8.82243798e-01 4.05760484e-03 9.71654048e-01 9.73574151e-01
#   9.99221979e-01]]

# %%
#Creamos matrices auxiliares para almacenar P(x_i | y)
arrayAuxPico = np.zeros(arrayTest.shape,dtype=float)
arrayAuxCuello = np.zeros(arrayTest.shape,dtype=float)
arrayAuxCachete = np.zeros(arrayTest.shape,dtype=float)

constante = 1/(math.sqrt(2*math.pi))
constante
# Out:
# 0.3989422804014327

# %%
for columnas in range(arrayTest.shape[1]):
    for filas in range(arrayTest.shape[0]):
        Ppico = constante * (1/math.sqrt(pow(varianzaPico[columnas],2))) * (math.exp(-((pow((arrayTest[filas][columnas]-mediaPico[columnas]),2))/(2*pow(varianzaPico[columnas],2)))))
        arrayAuxPico[filas][columnas] = Ppico
        Pcuello = constante * (1/math.sqrt(pow(varianzaCuello[columnas],2))) * (math.exp(-((pow((arrayTest[filas][columnas]-mediaCuello[columnas]),2))/(2*pow(varianzaCuello[columnas],2)))))
        arrayAuxCuello[filas][columnas] = Pcuello
        Pcachete = constante * (1/math.sqrt(pow(varianzaCachete[columnas],2))) * (math.exp(-((pow((arrayTest[filas][columnas]-mediaCachete[columnas]),2))/(2*pow(varianzaCachete[columnas],2)))))
        arrayAuxCachete[filas][columnas] = Pcachete

# %%
pred = pd.DataFrame(arrayAuxPico)
pred
# Out:
#            0             1             2         3              4  \
# 40  0.000521  9.057983e-09  1.023660e-05  0.006679  1.521193e-100
# 41  0.000522  9.057983e-09  3.049109e-01  0.017119   6.284981e-06
# 42  0.000521  9.057983e-09  4.120097e-01  0.017178   6.576511e-06
# 43  0.000521  9.057983e-09  5.055317e-01  0.017291   6.948237e-01
# 44  0.000522  9.057983e-09  4.213950e-01  0.017191   4.709085e+00
#
#                 5             6              7    8
# 0    0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 1    0.000000e+00  0.000000e+00   1.145613e-46  0.0
# 2    0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 3    0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 4    0.000000e+00  0.000000e+00   2.007090e-01  0.0
# 5    0.000000e+00  0.000000e+00   2.701044e-19  0.0
# 6    0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 7    0.000000e+00  0.000000e+00  4.247623e-259  0.0
# 8    0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 9    0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 10   0.000000e+00  0.000000e+00  4.557693e-123  0.0
# 11   0.000000e+00  0.000000e+00   4.276333e+02  0.0
# 12   0.000000e+00  0.000000e+00   3.061868e-95  0.0
# 13   8.225401e+03  0.000000e+00   1.342472e+01  0.0
# 14   0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 15   0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 16   0.000000e+00  0.000000e+00  4.993409e-166  0.0
# 17   0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 18   0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 19   3.981178e-58  1.753022e+03  6.491912e-214  0.0
# 20   0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 21   0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 22   0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 23   0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 24   0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 25   0.000000e+00  0.000000e+00   4.508560e-52  0.0
# 26   0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 27   0.000000e+00  0.000000e+00   5.155363e-02  0.0
# 28   0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 29   0.000000e+00  0.000000e+00   2.601457e-17  0.0
# 30   1.978931e-03  0.000000e+00   1.966370e-81  0.0
# 31   0.000000e+00  0.000000e+00  3.666366e-207  0.0
# 32   1.145455e-16  0.000000e+00   0.000000e+00  0.0
# 33   0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 34   4.307862e-96  0.000000e+00  2.542116e-144  0.0
# 35   0.000000e+00  0.000000e+00   3.221996e-10  0.0
# 36   0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 37   0.000000e+00  2.494097e-58  9.532742e-298  0.0
# 38   0.000000e+00  0.000000e+00   2.398625e-19  0.0
# 39   0.000000e+00  0.000000e+00   4.231361e+02  0.0
# 40   0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 41   0.000000e+00  1.039977e-02  3.475136e-165  0.0
# 42   0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 43   0.000000e+00  0.000000e+00   0.000000e+00  0.0
# 44  3.897797e-182  0.000000e+00  1.199446e-209  0.0

# %% [markdown]
# ### Inestabilidad númerica.
# Vemos que la moyoria de los valores 5,6,7 y 8 python los detecta como si fueran cero. Sin embargo, los valores reales no son cero, son valores aproximados a $1\times10^{-2250}$ (ingrese algunos a Wolfram). Esto lo consideramos como una inestabilidad numerica.
# <br>
# Para evitar este problema calculamos la siguiente ecuacion:
# <br>
# $$ln(P(x_i | y)) = ln \left( \frac{1}{\sqrt{2 \pi \sigma_{y}^{2}}} exp \left( - \frac{(x_y - \mu_y )^2}{2 \sigma_{y}^{2}}  \right)\right)$$
# <br>
# donde $ln(x)$ es el logaritmo natural de x. Realizando algebra sencilla encontramos que la ecuacion anterior es:
# $$ln(P(x_i | y)) = \left( \frac{-(\mu_y - x_y)^2}{2\sigma ^2} + ln\left( \frac{1}{\sigma}\right) - \frac{ln(2\pi)}{2} \right)$$
# <br>
# Por otro lado, veamos que:
# <br>
# $$ln(P(y| \vec{x})) \approx ln(P(y)\prod_{i=1}^{n}P(x_i | y))$$
# <br>
# Por propiedades de los logaritmos resulta ser:
# <br>
# $$ln(P(y| \vec{x})) \approx ln(P(y)) + \sum_{i=1}^{n}ln(P(x_i | y))$$
# <br>
#
# Dado que la predicción $\hat{y}$ escoge el valor maximo, aplicar el logaritmo natural a $P(y| \vec{x})$ no aporta información ya que el logaritmo es una función creciente en el intervalo $(0,\infty)$. Por lo que nuestra predicción $\hat{y}$ tambien será:
# <br>
# $$\hat{y} = argmax_y \left( ln(P(y)) + \sum_{i=1}^{n}ln(P(x_i | y))\right)$$
# <br>

# %%
#Creamos matrices auxiliares para almacenar P(x_i | y)
arrayAuxPico = np.zeros(arrayTest.shape,dtype=float)
arrayAuxCuello = np.zeros(arrayTest.shape,dtype=float)
arrayAuxCachete = np.zeros(arrayTest.shape,dtype=float)

# %%
#De lo anterior calculamos los logaritmos de P(x_i| y) 
#y guardamos los resultados en los arrays Auxiliares segun sea el caso
for columnas in range(arrayTest.shape[1]):
    for filas in range(arrayTest.shape[0]):
        Ppico = (-1/2)*((pow((-arrayTest[filas][columnas]+mediaPico[columnas]),2))/(pow(varianzaPico[columnas],2)))+(math.log((1/varianzaPico[columnas])))-((1/2)*math.log(2*math.pi))
        arrayAuxPico[filas][columnas] = Ppico
        Pcuello = (-1/2)*(((pow((-arrayTest[filas][columnas]+mediaCuello[columnas]),2)))/(pow(varianzaCuello[columnas],2)))+(math.log((1/varianzaCuello[columnas])))-((1/2)*math.log(2*math.pi))
        arrayAuxCuello[filas][columnas] = Pcuello
        Pcachete = (-1/2)*(((pow((-arrayTest[filas][columnas]+mediaCachete[columnas]),2)))/(pow(varianzaCachete[columnas],2)))+(math.log((1/varianzaCachete[columnas])))-((1/2)*math.log(2*math.pi))
        arrayAuxCachete[filas][columnas] = Pcachete

# %%
#Comprobamos visualmente que no haya inestabilidad numerica
predPico = pd.DataFrame(arrayAuxPico)
predPico
# Out:
#            0          1          2         3           4             5  \
# 0  -7.558960 -18.519619  -0.680537 -4.057443   -3.710215 -8.938733e+05
# 1  -7.558414 -18.519619  -0.906354 -4.091420    2.100209 -8.188050e+04
# 2  -7.563263 -18.519619  -1.266968 -4.074326   -3.710215 -1.844539e+06
# 3  -7.560832 -18.519619  -0.939950 -4.065856   -5.032364 -1.619418e+06
# 4  -7.558204 -18.519619  -2.819837 -4.126005    2.100209 -7.370118e+05
# 5  -7.558307 -18.519619  -1.098721 -4.066577    3.209108 -2.176265e+05
# 6  -7.562729 -18.519620  -0.643432 -4.059262   -2.526693 -7.802863e+05
# 7  -7.558384 -18.519619  -0.785580 -4.061547    3.209108 -8.441277e+05
# 8  -7.559740 -18.519619  -0.895645 -4.067630  -10.214512 -5.825621e+05
# 9  -7.559327 -18.519619  -0.631009 -4.058499    0.986953 -7.568929e+05
# 10 -7.558661 -18.519619  -2.480616 -4.104948    2.662140 -3.733296e+03
# 11 -7.558166 -18.519619  -1.087711 -4.068800    1.389102 -4.794824e+04
# 44 -8.495981 -21.246694 -1.538375 -5.341157   -28.353555 -22785.508789
#
#                6           7             8
# 0  -9.336465e+03    4.537566 -5.820433e+05
# 1  -8.391583e+03 -260.507590 -6.697155e+05
# 2  -3.183160e+04 -238.507719 -1.298994e+06
# 3  -9.038085e+03  -74.040991 -2.647878e+05
# 4  -4.792862e+03 -177.455163 -6.215450e+05
# 5  -8.036690e+04 -220.371065 -7.768480e+05
# 6  -8.182203e+04 -198.368579 -7.240149e+05
# 7  -7.475235e+02   -9.006069 -3.622968e+05
# 8  -5.689061e+03  -16.542392 -8.810894e+04
# 9  -2.281516e+04   -1.917251 -2.014639e+04
# 10 -4.311113e+05 -340.104606 -3.326279e+06
# 11 -1.565048e+03 -154.064823 -9.194724e+05
# 12 -6.691475e+04 -313.967804 -1.104739e+06
# 13 -1.341840e+03 -135.202350 -1.162252e+06
# 14 -1.834377e+04   -0.113312 -4.981866e+04
# 15 -3.287795e+08 -625.031384 -1.827543e+06
# 16 -2.885436e+07 -376.893079 -2.909833e+06
# 17 -5.473396e+06  -90.346289 -4.752967e+05
# 18 -1.000112e+07    3.384653 -1.103455e+05
# 19 -1.357655e+06  -15.603993 -2.120701e+04
# 20 -1.655578e+07   -0.945293 -1.286449e+06
# 21 -1.455993e+07    4.531119 -9.554687e+05
# 22 -5.493220e+06  -80.067002 -1.374134e+06
# 23 -8.089382e+07 -574.165276 -3.146083e+06
# 24 -6.002364e+06 -141.294818 -1.499316e+05
# 25 -5.486574e+06 -267.220133 -7.644354e+05
# 26 -2.957368e+08 -677.241425 -4.584806e+06
# 27 -2.022897e+07 -179.725598 -8.778717e+05
# 28 -9.933358e+07 -687.516120 -6.431586e+06
# 29 -1.849460e+07 -216.794264 -8.746177e+01
# 30 -2.558768e+05  -52.142587 -2.435220e+05
# 31 -4.876974e+06 -409.351154 -2.269447e+06
# 32 -1.276194e+05    1.720539 -1.704930e+05
# 33 -3.063382e+05    4.881874 -1.089884e+05
# 34 -3.365311e+06 -358.749666 -3.326036e+06
# 35 -2.564853e+06 -202.480651 -6.579973e+04
# 36 -3.892490e+05    2.988302 -3.649740e+05
# 37 -1.083337e+06   -4.693588 -9.878136e+05
# 38 -2.336785e+06 -220.462141 -4.116163e+06
# 39 -3.581503e+06 -148.945152 -3.301995e+06
# 40 -6.556299e+06 -513.940520 -2.983728e+06
# 41 -1.288271e+06 -376.203526 -4.057377e+06
# 42 -3.537694e+06 -621.719891 -5.875813e+06
# 43 -8.593317e+06 -583.641222 -6.270231e+06
# 44 -3.406696e+06 -411.244951 -3.162667e+06

# %%
#Dado que vamos a sumar las columnas vamos a tener un array resultante de 1 columna x 50 filas
#para cada conjunto de datos
PyxPico = np.zeros((45,1),dtype=float)
PyxCuello = np.zeros((45,1),dtype=float)
PyxCachete = np.zeros((45,1),dtype=float)

# %%
#Creamos variables auxiliares que almacenaran las sumas
Pypico = 0
Pycuello = 0
Pycachete = 0
#Ahora calculamos las sumas de todos las columnas para cada array
for filas in range(arrayTest.shape[0]):
    for columnas in range(arrayTest.shape[1]):
        Pypico += arrayAuxPico[filas][columnas]
        Pycuello += arrayAuxCuello[filas][columnas] 
        Pycachete += arrayAuxCachete[filas][columnas]
    #almacenamos los valores de la suma de las columnas para una fila fija en los vectores correspondientes
    PyxPico[filas][0] = Pypico + (1/3)
    PyxCuello[filas][0] = Pycuello + (1/3)
    PyxCachete[filas][0] = Pycachete + (1/3)
    Pypico = 0
    Pycuello = 0
    Pycachete = 0

# %%
#creamos un array que contenga las predicciones de acuerdo al valor maximo de entre los tres arrays
#PyxPico, PyxCuello ,PyxCachete. En la segunda columna escribiremos 0,1,2 si la prediccion se 
#trata de Pico, Cuello o Cachete respectivamente
prediccion = np.zeros((45,2),dtype=float)

#creamos variable auxiliar que contendra los valores maximos
#maximo = 0

#iteramos sobre los arrays PyxPico, PyxCuello ,PyxCachete para encontrar el maximo
for filas in range(PyxPico.shape[0]):
    maximo = max(PyxPico[filas][0],PyxCuello[filas][0],PyxCachete[filas][0])
    prediccion[filas][0]=maximo
    if maximo == PyxPico[filas][0]:
        prediccion[filas][1]=0
    elif maximo == PyxCuello[filas][0]:
        prediccion[filas][1]=1
    else:
        prediccion[filas][1]=2

# %%
#Convertimos el array a un dataframe y lo gradamos en la variable Prediccion
Prediccion = pd.DataFrame(prediccion)

#cambiamos los headers
Prediccion.rename(columns={0:'ValorMaximo',1:'ClasePredicha'}, inplace=True)

#mostramos el dataframe recien creado
Prediccion
# Out:
#      ValorMaximo  ClasePredicha
# 0  -5.917864e+05            2.0
# 1  -6.477374e+04            1.0
# 2  -1.339091e+06            2.0
# 3  -2.795146e+05            2.0
# 4  -4.968392e+05            1.0
# 5  -1.614943e+05            1.0
# 6  -8.061797e+05            2.0
# 7  -3.632346e+05            2.0
# 8  -9.413421e+04            2.0
# 9  -4.300921e+04            2.0
# 10 -3.079508e+05            1.0
# 11 -5.788953e+04            1.0
# 12 -3.590926e+05            1.0
# 13 -2.330312e+04            0.0
# 14 -7.003020e+04            2.0
# 15 -1.150405e+05            1.0
# 16 -2.766998e+05            1.0
# 17 -3.878275e+05            1.0
# 18 -2.022734e+05            1.0
# 19 -4.727198e+04            1.0
# 20 -7.066193e+05            1.0
# 21 -5.401501e+05            1.0
# 22 -7.188298e+05            1.0
# 23 -3.066554e+05            1.0
# 24 -2.188049e+05            1.0
# 25 -2.120350e+04            1.0
# 26 -5.346456e+05            1.0
# 27 -2.279884e+04            1.0
# 28 -8.524455e+05            1.0
# 29 -9.104663e+04            1.0
# 30 -3.402006e+03            1.0
# 31 -1.692132e+05            1.0
# 32 -9.181321e+03            1.0
# 33 -6.442542e+04            1.0
# 34 -3.063398e+05            1.0
# 35 -1.114924e+05            1.0
# 36 -1.221090e+04            1.0
# 37 -6.771876e+05            1.0
# 38 -4.576075e+05            1.0
# 39 -3.186402e+05            1.0
# 40 -2.652230e+05            1.0
# 41 -4.247280e+05            1.0
# 42 -7.404543e+05            1.0
# 43 -8.216472e+05            1.0
# 44 -2.835695e+05            1.0

# %%
#Convertimos los valores de la columna ClasePredicha a string, esto para poder traducir las clases como ya se establecio
Prediccion['ClasePredicha'] = np.where(Prediccion['ClasePredicha']==0 , 'Pico', (np.where(Prediccion['ClasePredicha'] == 1, 'Cuello', 'Cachete')))

Prediccion
# Out:
#      ValorMaximo ClasePredicha
# 0  -5.917864e+05       Cachete
# 1  -6.477374e+04        Cuello
# 2  -1.339091e+06       Cachete
# 3  -2.795146e+05       Cachete
# 4  -4.968392e+05        Cuello
# 5  -1.614943e+05        Cuello
# 6  -8.061797e+05       Cachete
# 7  -3.632346e+05       Cachete
# 8  -9.413421e+04       Cachete
# 9  -4.300921e+04       Cachete
# 10 -3.079508e+05        Cuello
# 11 -5.788953e+04        Cuello
# 12 -3.590926e+05        Cuello
# 13 -2.330312e+04          Pico
# 14 -7.003020e+04       Cachete
# 15 -1.150405e+05        Cuello
# 16 -2.766998e+05        Cuello
# 17 -3.878275e+05        Cuello
# 18 -2.022734e+05        Cuello
# 19 -4.727198e+04        Cuello
# 20 -7.066193e+05        Cuello
# 21 -5.401501e+05        Cuello
# 22 -7.188298e+05        Cuello
# 23 -3.066554e+05        Cuello
# 24 -2.188049e+05        Cuello
# 25 -2.120350e+04        Cuello
# 26 -5.346456e+05        Cuello
# 27 -2.279884e+04        Cuello
# 28 -8.524455e+05        Cuello
# 29 -9.104663e+04        Cuello
# 30 -3.402006e+03        Cuello
# 31 -1.692132e+05        Cuello
# 32 -9.181321e+03        Cuello
# 33 -6.442542e+04        Cuello
# 34 -3.063398e+05        Cuello
# 35 -1.114924e+05        Cuello
# 36 -1.221090e+04        Cuello
# 37 -6.771876e+05        Cuello
# 38 -4.576075e+05        Cuello
# 39 -3.186402e+05        Cuello
# 40 -2.652230e+05        Cuello
# 41 -4.247280e+05        Cuello
# 42 -7.404543e+05        Cuello
# 43 -8.216472e+05        Cuello
# 44 -2.835695e+05        Cuello

# %%
##A la tabla prediccion le pegamos la tabla ClasesReales
Prediccion['Clase Real'] = ClasesReales
Prediccion
# Out:
#      ValorMaximo ClasePredicha Clase Real
# 0  -5.917864e+05       Cachete    Cachete
# 1  -6.477374e+04        Cuello    Cachete
# 2  -1.339091e+06       Cachete    Cachete
# 3  -2.795146e+05       Cachete    Cachete
# 4  -4.968392e+05        Cuello    Cachete
# 5  -1.614943e+05        Cuello    Cachete
# 6  -8.061797e+05       Cachete    Cachete
# 7  -3.632346e+05       Cachete    Cachete
# 8  -9.413421e+04       Cachete    Cachete
# 9  -4.300921e+04       Cachete    Cachete
# 10 -3.079508e+05        Cuello    Cachete
# 11 -5.788953e+04        Cuello    Cachete
# 12 -3.590926e+05        Cuello    Cachete
# 13 -2.330312e+04          Pico    Cachete
# 14 -7.003020e+04       Cachete    Cachete
# 15 -1.150405e+05        Cuello     Cuello
# 16 -2.766998e+05        Cuello     Cuello
# 17 -3.878275e+05        Cuello     Cuello
# 18 -2.022734e+05        Cuello     Cuello
# 19 -4.727198e+04        Cuello     Cuello
# 20 -7.066193e+05        Cuello     Cuello
# 21 -5.401501e+05        Cuello     Cuello
# 22 -7.188298e+05        Cuello     Cuello
# 23 -3.066554e+05        Cuello     Cuello
# 24 -2.188049e+05        Cuello     Cuello
# 25 -2.120350e+04        Cuello     Cuello
# 26 -5.346456e+05        Cuello     Cuello
# 27 -2.279884e+04        Cuello     Cuello
# 28 -8.524455e+05        Cuello     Cuello
# 29 -9.104663e+04        Cuello     Cuello
# 30 -3.402006e+03        Cuello       Pico
# 31 -1.692132e+05        Cuello       Pico
# 32 -9.181321e+03        Cuello       Pico
# 33 -6.442542e+04        Cuello       Pico
# 34 -3.063398e+05        Cuello       Pico
# 35 -1.114924e+05        Cuello       Pico
# 36 -1.221090e+04        Cuello       Pico
# 37 -6.771876e+05        Cuello       Pico
# 38 -4.576075e+05        Cuello       Pico
# 39 -3.186402e+05        Cuello       Pico
# 40 -2.652230e+05        Cuello       Pico
# 41 -4.247280e+05        Cuello       Pico
# 42 -7.404543e+05        Cuello       Pico
# 43 -8.216472e+05        Cuello       Pico
# 44 -2.835695e+05        Cuello       Pico

# %%
##Contamos la cantidad de errores, para ello creamos una nueva columna Comparacion
##la cual tendra valor 0 si la predicion y la clase son iguales, 1 en otro caso
Prediccion['Comparacion'] = np.where(Prediccion['ClasePredicha'] != Prediccion['Clase Real'], 1, 0)

#mostramos el dataframe
Prediccion
# Out:
#      ValorMaximo ClasePredicha Clase Real  Comparacion
# 0  -5.917864e+05       Cachete    Cachete            0
# 1  -6.477374e+04        Cuello    Cachete            1
# 2  -1.339091e+06       Cachete    Cachete            0
# 3  -2.795146e+05       Cachete    Cachete            0
# 4  -4.968392e+05        Cuello    Cachete            1
# 5  -1.614943e+05        Cuello    Cachete            1
# 6  -8.061797e+05       Cachete    Cachete            0
# 7  -3.632346e+05       Cachete    Cachete            0
# 8  -9.413421e+04       Cachete    Cachete            0
# 9  -4.300921e+04       Cachete    Cachete            0
# 10 -3.079508e+05        Cuello    Cachete            1
# 11 -5.788953e+04        Cuello    Cachete            1
# 12 -3.590926e+05        Cuello    Cachete            1
# 13 -2.330312e+04          Pico    Cachete            1
# 14 -7.003020e+04       Cachete    Cachete            0
# 15 -1.150405e+05        Cuello     Cuello            0
# 16 -2.766998e+05        Cuello     Cuello            0
# 17 -3.878275e+05        Cuello     Cuello            0
# 18 -2.022734e+05        Cuello     Cuello            0
# 19 -4.727198e+04        Cuello     Cuello            0
# 20 -7.066193e+05        Cuello     Cuello            0
# 21 -5.401501e+05        Cuello     Cuello            0
# 22 -7.188298e+05        Cuello     Cuello            0
# 23 -3.066554e+05        Cuello     Cuello            0
# 24 -2.188049e+05        Cuello     Cuello            0
# 25 -2.120350e+04        Cuello     Cuello            0
# 26 -5.346456e+05        Cuello     Cuello            0
# 27 -2.279884e+04        Cuello     Cuello            0
# 28 -8.524455e+05        Cuello     Cuello            0
# 29 -9.104663e+04        Cuello     Cuello            0
# 30 -3.402006e+03        Cuello       Pico            1
# 31 -1.692132e+05        Cuello       Pico            1
# 32 -9.181321e+03        Cuello       Pico            1
# 33 -6.442542e+04        Cuello       Pico            1
# 34 -3.063398e+05        Cuello       Pico            1
# 35 -1.114924e+05        Cuello       Pico            1
# 36 -1.221090e+04        Cuello       Pico            1
# 37 -6.771876e+05        Cuello       Pico            1
# 38 -4.576075e+05        Cuello       Pico            1
# 39 -3.186402e+05        Cuello       Pico            1
# 40 -2.652230e+05        Cuello       Pico            1
# 41 -4.247280e+05        Cuello       Pico            1
# 42 -7.404543e+05        Cuello       Pico            1
# 43 -8.216472e+05        Cuello       Pico            1
# 44 -2.835695e+05        Cuello       Pico            1

# %%
#Dado que en la columna comparacion solo hay 0 o 1 sumamos los valores en toda lka columna mediante la funcion sum()
Errores = Prediccion['Comparacion'].sum()
print('Hay %d muestras mal clasificadas en el dataset de validacion.' %Errores + ' Corresponde al %.2f porciento de error' %(Errores*100/Prediccion.shape[0]))
# Out:
# Hay 22 muestras mal clasificadas en el dataset de validacion. Corresponde al 48.89 porciento de error

# %% [markdown]
# Veamos que el clasificador es malisimo haciendo su trabajo, aparentemente es igual de efectivo que echar un volado. Veamos las distribuciones de cada clase con su respectiva columna. Esto para inferir algunas cosas e incluso reducir el error eliminando alguna de las clases, que a vista, podria eliminarse el pico o el cuello ya que sus colores son muy parecidos, pero esto se vera hasta observar las distribuciones.

# %%
trainPico['Clase'] = 'Pico'
trainCuello['Clase'] = 'Cuello'
trainCachete['Clase'] = 'Cachete'

frames = [trainCachete, trainCuello, trainPico]
Train = pd.concat(frames)
Train.reset_index(drop=True,inplace=True)
Train
# Out:
#          media      varianza  asimetria   curtosis  entropia  contraste  \
# 0    40.355469   4056.120205   1.659287   4.891052  0.999604   0.005255
# 1    75.875000  25896.988235   3.405525  16.730584  0.995593   0.009116
# 2    85.234375  15129.168382   1.844647   7.027741  0.990071   0.008402
# 3    18.925781    720.147411   1.268384   3.504861  0.988699   0.005265
# 4    69.968750  10482.210784   1.211034   3.279414  0.999956   0.003339
# ..         ...           ...        ...        ...       ...        ...
# 100  49.804688   4703.796998   1.905690   7.911403  0.993651   0.003250
# 101  83.222656  19600.597289   2.223662   7.362899  0.993651   0.005232
# 102  30.265625   5040.799755   2.834926  10.857817  0.908910   0.001484
# 103  52.550781   5171.126823   1.645270   5.639915  0.995593   0.003663
# 104  54.734375   6903.984069   2.803058  10.951779  0.757878   0.007674
#
#      correlacion   energia  homogeneidad    Clase
# 0       0.991308  0.951549      0.998916  Cachete
# 1       0.995240  0.911026      0.998441  Cachete
# 2       0.993781  0.899793      0.998115  Cachete
# 3       0.986051  0.976926      0.999294  Cachete
# 4       0.993949  0.917516      0.998834  Cachete
# ..           ...       ...           ...      ...
# 100     0.983119  0.954978      0.999012     Pico
# 101     0.989190  0.902683      0.998393     Pico
# 102     0.970416  0.965168      0.999391     Pico
# 103     0.980937  0.948790      0.999208     Pico
# 104     0.974749  0.956409      0.998801     Pico
#
# [105 rows x 10 columns]

# %%
#Mostramos la correlacion entre variables de forma grafica
import seaborn as sns
g = sns.pairplot(Train,hue='Clase',palette="husl",corner=True)
g.fig.set_size_inches(15,15)

# %%
#Para mostrar la relacion entre las variables Longitud y Ancho de todas las especies usamos 
#la funcion .corr() que regresa una matriz de correlacion (Este metodo es de pandas)
sns.heatmap(Train.corr(),annot=True,fmt='.2f')

# %% [markdown]
# Claramente se ve que un clasificador para estos datos no será muy bueno, ya que los histogramas entre variables se translapan para la mayoria de las variables. Aun cuando se descarte una clase cualquiera, esto no mejoraria debido a este problema.

# %%
#creamos nuestros datos Train para entrenar con la funcion de scikitlearn
trainPico['Clase'] = 0 #Pico
trainCuello['Clase'] = 1 #'Cuello'
trainCachete['Clase'] = 2#'Cachete'

frames = [trainCachete, trainCuello, trainPico]
Train = pd.concat(frames)
Train.reset_index(drop=True,inplace=True)
Train
# Out:
#          media      varianza  asimetria   curtosis  entropia  contraste  \
# 0    40.355469   4056.120205   1.659287   4.891052  0.999604   0.005255
# 1    75.875000  25896.988235   3.405525  16.730584  0.995593   0.009116
# 2    85.234375  15129.168382   1.844647   7.027741  0.990071   0.008402
# 3    18.925781    720.147411   1.268384   3.504861  0.988699   0.005265
# 4    69.968750  10482.210784   1.211034   3.279414  0.999956   0.003339
# ..         ...           ...        ...        ...       ...        ...
# 100  49.804688   4703.796998   1.905690   7.911403  0.993651   0.003250
# 101  83.222656  19600.597289   2.223662   7.362899  0.993651   0.005232
# 102  30.265625   5040.799755   2.834926  10.857817  0.908910   0.001484
# 103  52.550781   5171.126823   1.645270   5.639915  0.995593   0.003663
# 104  54.734375   6903.984069   2.803058  10.951779  0.757878   0.007674
#
#      correlacion   energia  homogeneidad  Clase
# 0       0.991308  0.951549      0.998916      2
# 1       0.995240  0.911026      0.998441      2
# 2       0.993781  0.899793      0.998115      2
# 3       0.986051  0.976926      0.999294      2
# 4       0.993949  0.917516      0.998834      2
# ..           ...       ...           ...    ...
# 100     0.983119  0.954978      0.999012      0
# 101     0.989190  0.902683      0.998393      0
# 102     0.970416  0.965168      0.999391      0
# 103     0.980937  0.948790      0.999208      0
# 104     0.974749  0.956409      0.998801      0
#
# [105 rows x 10 columns]

# %%
#creamos nuestros datos Test para entrenar con la funcion de scikitlearn
testPico['Clase'] = 0#'Pico'
testCuello['Clase'] = 1 #'Cuello'
testCachete['Clase'] = 2#'Cachete'

frames = [testCachete, testCuello, testPico]
Test = pd.concat(frames)
Test.reset_index(drop=True,inplace=True)
Test.head(10)
# Out:
#         media      varianza  asimetria   curtosis  entropia  contraste  \
# 0   83.890625   9466.631127   1.698557   7.044050  0.851806   0.013920
# 1   33.515625   2414.705637   2.491578  13.102371  0.935456   0.007190
# 2  129.976562  27044.407292   1.089453   2.849137  0.851806   0.018132
# 3  108.781250  17184.665686   1.345566   4.095803  0.846354   0.017259
# 4   41.867188   9897.197978   3.503589  15.631245  0.935456   0.013032
# 5   37.195312   1874.989154   1.209834   3.970218  0.912999   0.009031
# 6  125.851562  33358.456311   1.815782   5.696459  0.857148   0.013286
# 7   70.285156   8604.581112   1.517928   4.998017  0.912999   0.013647
# 8   96.023438  20198.117096   1.389435   3.795411  0.994666   0.012060
# 9   90.093750  21156.775490   1.918872   6.027364  0.945373   0.013150
#
#    correlacion   energia  homogeneidad  Clase
# 0     0.994203  0.901224      0.997731      2
# 1     0.992016  0.959531      0.998659      2
# 2     0.995152  0.850431      0.997510      2
# 3     0.994185  0.873381      0.997877      2
# 4     0.993885  0.950004      0.998641      2
# 5     0.989789  0.955148      0.998696      2
# 6     0.996401  0.855026      0.997679      2
# 7     0.992761  0.916647      0.997825      2
# 8     0.993957  0.887892      0.998004      2
# 9     0.994834  0.894740      0.998095      2

# %%
#convertimos los datos Train a un array 
X_train = pd.DataFrame(Train.drop("Clase",axis=1)).to_numpy()
Y_train = pd.DataFrame(Train["Clase"]).to_numpy()

#convertimos los datos Test a un array 
X_test = pd.DataFrame(Test.drop("Clase",axis=1)).to_numpy()
Y_test = pd.DataFrame(Test["Clase"]).to_numpy()

#Entrenamos el clasificador bayesiano con la funcion de scikitlearn
#Y_pred son los valores predichos por el clasificador
gnb = GaussianNB()
Y_pred = gnb.fit(X_train, Y_train.ravel()).predict(X_test)

#imprimimos la tasa de errores
print("La cantidad de errores de %d muestras es de : %d" % (X_test.shape[0], (Y_test.T != Y_pred).sum()))
print("Representa el %.2f porciento" %(100*((Y_test.T != Y_pred).sum())/X_test.shape[0]))
# Out:
# La cantidad de errores de 45 muestras es de : 17
# Representa el 37.78 porciento

# %% [markdown]
# Notemos que el porcentaje de error es menor comparado con el implementado de forma manual, esto se debe a que la implementacion de la funcion tiene por default el suavizado de la place. La documentacion comenta unicamente lo siguiente:
#
# * var_smoothingfloat, optional (default=1e-9): Portion of the largest variance of all features that is added to variances for calculation stability.
#
# Y no es claro como evitar que el clasificador use suavizado de Laplace. Veamos como este suavizado afecta el procentaje de error

# %%
#Entrenamos el clasificador bayesiano con la funcion de scikitlearn
#Y_pred son los valores predichos por el clasificador con suavizado de 0
gnb = GaussianNB(var_smoothing=0)
Y_pred = gnb.fit(X_train, Y_train.ravel()).predict(X_test)

#imprimimos la tasa de errores
print("La cantidad de errores de %d muestras es de : %d" % (X_test.shape[0], (Y_test.T != Y_pred).sum()))
print("Representa el %.2f porciento" %(100*((Y_test.T != Y_pred).sum())/X_test.shape[0]))
# Out:
# La cantidad de errores de 45 muestras es de : 7
# Representa el 15.56 porciento

# %%
#Entrenamos el clasificador bayesiano con la funcion de scikitlearn
#Y_pred son los valores predichos por el clasificador con suavizado de 2
gnb = GaussianNB(var_smoothing=2)
Y_pred = gnb.fit(X_train, Y_train.ravel()).predict(X_test)

#imprimimos la tasa de errores
print("La cantidad de errores de %d muestras es de : %d" % (X_test.shape[0], (Y_test.T != Y_pred).sum()))
print("Representa el %.2f porciento" %(100*((Y_test.T != Y_pred).sum())/X_test.shape[0]))
# Out:
# La cantidad de errores de 45 muestras es de : 27
# Representa el 60.00 porciento
